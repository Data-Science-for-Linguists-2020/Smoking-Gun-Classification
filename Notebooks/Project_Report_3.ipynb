# %% [markdown]
# # Project Report III: Finalizing Data Cleaning, Machine Learning
# ___
# **Brief:**<br>
# In this report, I'll expand to the data cleaning process to all of the users in the Enron directory, explore the text and tag data, and finally use a bag-of-words approach to make a simple classifier.
#
# **Sections:**<br>
# 1. [Searching All Files](#1)
#     - [Trying OS](#1a)
#     - [Adapting Old Functions](#1b)
#     - [A Complete DataFrame](#1c)
#     - [Summary](#1d)
# 2. [Preparing for Unsupervised Learning](#2)
# ___

# %% [markdown]
# ## Searching All Files
# <a id='1a'>

# %% [markdown]
# ***Trying OS***

# %%
#imports and setting root
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import nltk
from nltk.corpus import PlaintextCorpusReader as cr
import pandas as pd
import numpy as np
import os
import email.parser
corpus_root = '../../../../../../'

# %%
#exploring os.walk
path = corpus_root + "mini_enron/"
#this will change to "Enron_Emails/maildir/" for a full batch run. Mini Enron runs on 32,000 or so files.
#for file in os.walk(path):
    #file[0] #filepath of each file
    #file[1] #directory (names) in each file
    #file[2] #files of every directory, rock bottom

# %% [markdown]
# *Note*: I could see how this module would be really useful, but honestly it looks like more of a summer project than something I can effectively use this term.
# <a id='1b'>

# %% [markdown]
# ***Adapting Old Functions***

# %%
for name in os.listdir(path):
    relpath = path + name + "/"
    print(name + "'s folders: ")
    #for folder in os.listdir(relpath):
        #filepath = relpath + folder + "/"
        #print("folder<" + folder + ">: ")
        #for file in os.listdir(filepath):
# Out:
# allen-p's folders:
# arnold-j's folders:
# arora-h's folders:
# badeer-r's folders:
# bailey-s's folders:
# bass-e's folders:
# baughman-d's folders:
# beck-s's folders:
# benson-r's folders:
# blair-l's folders:
# brawner-s's folders:
# buy-r's folders:
# campbell-l's folders:
# carson-m's folders:
# cash-m's folders:
# causholli-m's folders:
# corman-s's folders:
# crandell-s's folders:
# cuilla-m's folders:
# dasovich-j's folders:
# davis-d's folders:
# dean-c's folders:
# delainey-d's folders:
# derrick-j's folders:
# dickson-s's folders:
# donoho-l's folders:
# donohoe-t's folders:
# dorland-c's folders:
# ermis-f's folders:
# farmer-d's folders:
# fischer-m's folders:
# forney-j's folders:
# fossum-d's folders:
# gang-l's folders:
# gay-r's folders:
# geaccone-t's folders:
# germany-c's folders:
# gilbertsmith-d's folders:
# giron-d's folders:
# griffith-j's folders:
# grigsby-m's folders:
# guzman-m's folders:
# haedicke-m's folders:
# hain-m's folders:
# harris-s's folders:
# hayslett-r's folders:
# heard-m's folders:
# hendrickson-s's folders:
# hernandez-j's folders:
# hodge-j's folders:
# holst-k's folders:
# horton-s's folders:
# hyatt-k's folders:
# hyvl-d's folders:
# jones-t's folders:
# kaminski-v's folders:
# kean-s's folders:
# keavey-p's folders:
# keiser-k's folders:
# king-j's folders:
# kitchen-l's folders:
# kuykendall-t's folders:
# lavorato-j's folders:
# lay-k's folders:
# lenhart-m's folders:
# lewis-a's folders:
# linder-e's folders:
# lokay-m's folders:
# lokey-t's folders:
# love-p's folders:
# lucci-p's folders:

# %% [markdown]
# *Note*: This is the old "readEmailHead" method, but now we can simplify the parameters.

# %%
def readEmailHead(file):
    with open(file) as fd:
        pp = email.parser.Parser()
        header = pp.parse(fd, headersonly=True) #where the magic happens. works on all MIME email formats.
    return header

# %%
emails = []
folders = []
users = []
fileErrors = 0
folderErrors = 0
totalEmails = 31000
for name in os.listdir(path):
    relpath = path + name + "/"
    print(name + " loaded")
    for folder in os.listdir(relpath):
        filepath = relpath + folder + "/"
        try:
            for file in os.listdir(filepath):
                try:
                    emails.append(readEmailHead(filepath+file))
                    users.append(name)
                    folders.append(folder)
                except:
                    #print("file error")
                    fileErrors += 1
                    continue
        except:
            #print("folder error")
            folderErrors += 1
            continue
totalErrors = fileErrors+folderErrors
accuracy = 1-totalErrors/totalEmails
print("users loaded with " + (str)(totalErrors) + " total errors, at a " + (str)(accuracy) + "% accuracy")
# Out:
# allen-p loaded
# arnold-j loaded
# arora-h loaded
# badeer-r loaded
# bailey-s loaded
# bass-e loaded
# baughman-d loaded
# beck-s loaded
# benson-r loaded
# blair-l loaded
# brawner-s loaded
# buy-r loaded
# campbell-l loaded
# carson-m loaded
# cash-m loaded
# causholli-m loaded
# corman-s loaded
# crandell-s loaded
# cuilla-m loaded
# dasovich-j loaded
# davis-d loaded
# dean-c loaded
# delainey-d loaded
# derrick-j loaded
# dickson-s loaded
# donoho-l loaded
# donohoe-t loaded
# dorland-c loaded
# ermis-f loaded
# farmer-d loaded
# fischer-m loaded
# forney-j loaded
# fossum-d loaded
# gang-l loaded
# gay-r loaded
# geaccone-t loaded
# germany-c loaded
# gilbertsmith-d loaded
# giron-d loaded
# griffith-j loaded
# grigsby-m loaded
# guzman-m loaded
# haedicke-m loaded
# hain-m loaded
# harris-s loaded
# hayslett-r loaded
# heard-m loaded
# hendrickson-s loaded
# hernandez-j loaded
# hodge-j loaded
# holst-k loaded
# horton-s loaded
# hyatt-k loaded
# hyvl-d loaded
# jones-t loaded
# kaminski-v loaded
# kean-s loaded
# keavey-p loaded
# keiser-k loaded
# king-j loaded
# kitchen-l loaded
# kuykendall-t loaded
# lavorato-j loaded
# lay-k loaded
# lenhart-m loaded
# lewis-a loaded
# linder-e loaded
# lokay-m loaded
# lokey-t loaded
# love-p loaded
# lucci-p loaded
# users loaded with 303 total errors, at a 0.990225806451613% accuracy

# %% [markdown]
# *Note*: Why so many errors? Take a look at the file hierarchy where the errors arise and you'll see more folders.

# %%
#first thing we do... save them emails.
#import pickle
#file = open('emails', 'wb')
#pickle.dump(emails, file, -1)
#file.close()

# %%
def getText(mail):
    if mail.is_multipart():
        for payload in mail.get_payload():
        # if payload.is_multipart(): ...
            return payload.get_payload()
    else:
        return mail.get_payload()

# %%
texts = []
for email in emails:
    texts.append(getText(email))

# %%
len(folders)
len(users)
len(texts)
len(emails)
emails[:10]
emails[0].values()
# Out:
# 277298
# 277298
# 277298
# 277298
# [<email.message.Message at 0x10272f10>,
#  <email.message.Message at 0x10272f30>,
#  <email.message.Message at 0x10272ed0>,
#  <email.message.Message at 0x10272ef0>,
#  <email.message.Message at 0x10278310>,
#  <email.message.Message at 0x10278650>,
#  <email.message.Message at 0x10278850>,
#  <email.message.Message at 0x10278670>,
#  <email.message.Message at 0x10278610>,
#  <email.message.Message at 0x10272e90>]
# ['<29790972.1075855665306.JavaMail.evans@thyme>',
#  'Wed, 13 Dec 2000 18:41:00 -0800 (PST)',
#  '1.11913372.-2@multexinvestornetwork.com',
#  'pallen@enron.com',
#  "December 14, 2000 - Bear Stearns' predictions for telecom in Latin\n America",
#  '1.0',
#  'text/plain; charset=us-ascii',
#  '7bit',
#  'Multex Investor <1.11913372.-2@multexinvestornetwork.com>',
#  '<pallen@enron.com>',
#  '',
#  '',
#  '\\Phillip_Allen_Dec2000\\Notes Folders\\All documents',
#  'Allen-P',
#  'pallen.nsf']

# %%
emails[0].keys()
# Out:
# ['Message-ID',
#  'Date',
#  'From',
#  'To',
#  'Subject',
#  'Mime-Version',
#  'Content-Type',
#  'Content-Transfer-Encoding',
#  'X-From',
#  'X-To',
#  'X-cc',
#  'X-bcc',
#  'X-Folder',
#  'X-Origin',
#  'X-FileName']

# %% [markdown]
# <a id='1c'>

# %% [markdown]
# ***A Full DataFrame***

# %%
import pickle
file = open('../pickles/df_keys', 'rb')
df_keys = pickle.load(file)
file.close()

# %%
def makeHeaderDF(emails):
    values = []
    for email in emails:
        values.append(email.values())
    email_df = pd.DataFrame(values, columns=df_keys)
    return email_df

# %%
emails_df = makeHeaderDF(emails)
emails_df["Text"] = texts
emails_df["Folder"] = folders
emails_df["User"] = users

# %%
emails_df.head()
# Out:
#                                       Message-ID  \
# 0  <29790972.1075855665306.JavaMail.evans@thyme>
# 1  <21975671.1075855665520.JavaMail.evans@thyme>
# 2   <7452188.1075855667684.JavaMail.evans@thyme>
# 3  <23790115.1075855667708.JavaMail.evans@thyme>
# 4   <5860470.1075855667730.JavaMail.evans@thyme>
#
#                                     Date  \
# 0  Wed, 13 Dec 2000 18:41:00 -0800 (PST)
# 1  Wed, 13 Dec 2000 08:35:00 -0800 (PST)
# 2   Mon, 9 Oct 2000 07:16:00 -0700 (PDT)
# 3   Mon, 9 Oct 2000 07:00:00 -0700 (PDT)
# 4   Thu, 5 Oct 2000 06:26:00 -0700 (PDT)
#
#                                       From                            To  \
# 0  1.11913372.-2@multexinvestornetwork.com              pallen@enron.com
# 1              messenger@ecm.bloomberg.com  Bloomberg Power Lines Report
# 2                  phillip.allen@enron.com         keith.holst@enron.com
# 3                  phillip.allen@enron.com         keith.holst@enron.com
# 4                  phillip.allen@enron.com      david.delainey@enron.com
#
#                                              Subject  \
# 0  December 14, 2000 - Bear Stearns' predictions ...
# 1                                                1.0
# 2        Consolidated positions: Issues & To Do list
# 3        Consolidated positions: Issues & To Do list
# 4
#
#                                    Cc                  Mime-Version  \
# 0                                 1.0  text/plain; charset=us-ascii
# 1  text/plain; charset=ANSI_X3.4-1968              quoted-printable
# 2                                 1.0  text/plain; charset=us-ascii
# 3                                 1.0  text/plain; charset=us-ascii
# 4                                 1.0  text/plain; charset=us-ascii
#
#                                     Content-Type  \
# 0                                           7bit
# 1  "Bloomberg.com" <messenger@ecm.bloomberg.com>
# 2                                           7bit
# 3                                           7bit
# 4                                           7bit
#
#                            Content-Transfer-Encoding                 Bcc  \
# 0  Multex Investor <1.11913372.-2@multexinvestorn...  <pallen@enron.com>
# 1                           (undisclosed-recipients)
# 2                                    Phillip K Allen         Keith Holst
# 3                                    Phillip K Allen         Keith Holst
# 4                                    Phillip K Allen    David W Delainey
#
#   X-From                                               X-To  \
# 0
# 1         \Phillip_Allen_Dec2000\Notes Folders\All docum...
# 2
# 3
# 4
#
#                                                 X-cc       X-bcc    X-Folder  \
# 0  \Phillip_Allen_Dec2000\Notes Folders\All docum...     Allen-P  pallen.nsf
# 1                                            Allen-P  pallen.nsf        None
# 2  \Phillip_Allen_Dec2000\Notes Folders\All docum...     Allen-P  pallen.nsf
# 3  \Phillip_Allen_Dec2000\Notes Folders\All docum...     Allen-P  pallen.nsf
# 4  \Phillip_Allen_Dec2000\Notes Folders\All docum...     Allen-P  pallen.nsf
#
#   X-Origin X-FileName                                               Text  \
# 0     None       None  In today's Daily Update you'll find free repor...
# 1     None       None  Here is today's copy of Bloomberg Power Lines....
# 2     None       None  ---------------------- Forwarded by Phillip K ...
# 3     None       None  ---------------------- Forwarded by Phillip K ...
# 4     None       None  Dave, \n\n Here are the names of the west desk...
#
#           Folder     User
# 0  all_documents  allen-p
# 1  all_documents  allen-p
# 2  all_documents  allen-p
# 3  all_documents  allen-p
# 4  all_documents  allen-p

# %% [markdown]
# <a id='1d'>

# %% [markdown]
# ### Searching All Files: Summary
# In the past three sections, we were finally able to load the vast majority of the Enron Corpus into Python objects. So how'd we do it, and why'd it take so long? This summary will act as a summary on the Data Organization process as a whole.
# 1. **New Techniques: OS**
#     - The OS library is famed for its ability to parse through files concisely, so I tried to use its *.walk(path)* command. This command will perform a traversal across the entire directory, as well as any subdirectories within. Sounds perfect for my project! Unfortunately, the command returned a lot more than I really needed. Feel free to uncomment my outputs, see for yourself! Just couldn't see myself getting anything productive out of the mess of a list.<br><br>
# 2. **The Final Reader**
#     - My final reader actually uses the OS library as well, but it really only uses one command: *.listdir()*. This command is quite simple: it just returns the contents of a directory. This is *much* simpler than *os.walk()*, so I just iterated across every directory, opening every item in each of the top two directories (users, folders) and then parsing every item in the bottom directories (should be all files). Since this is likely to be the way I traverse this data from now on, here's a few things to know:
#         - For the most part, this has excellent coverage. When I run this again, I'm going to be sure to include a counter of errors so I can actually report out on this, but it was mostly very efficient--only two things trip it up. The first exception comes from stray files that are in the user level folders, for instance *allen-p*. Sometimes there's just a stray file name *1* hanging around in there. The second exception is thrown for a more legitimate reason: the bottom isn't always the bottom. Every once in a while, there is a user that has folders within their folders. My search feeds those folders into a method that takes files. Error. That being said, these errors combined only crashed my search after it loaded 10 or so users, and any given error probably only skips 1-10 files.
#         - This search is predicated on a specific shape of the file hierarchy. Like I mentioned above, this search is two folders deep, then it reads through all of the files. This won't work on other structures, probably why os.walk() exists.
#     - As a final thought about this search, I would really like to use the CRC for it. The search has been going on for a few hours now and is severly hampering my progress. As of now, I'm going to have to abandon using the whole corpus and go with a reduced version. The one problem with using research computing is getting the Enron Corpus onto the CRC, which isn't really a drag and drop situation.<br><br>
# 3. **Why'd It Take So Long?**<br>
#    This question is mostly for me, as the time really feels like it got away from me on this one, but if I write convincingly enough maybe it'll help my grade too.
#     - **I spent a lot of time getting familiar with two libraries: email.parser and OS.** Before I learned about these (*ESPECIALLY EMAIL.PARSER*), I spend lots of time doing the code equivalent of kicking and screaming.
#     - **I didn't spend enough time planning ahead.** This is probably the biggest mistake that cost me time. A lot of times I really failed to consider what I would be doing in the future and how that affected what functions/libraries I made/utilized. A perfect example of this is the recent *readEmailHead* function, or more poignantly, the *makeEmailDF* function. I wrote them twice for little to no reason.
#     - **I didn't pay close enough attention to my data.** This goes hand in hand with the above comment, and applies mostly early on. If I did this all over again, I would have definitely sketched out an entire plan of attack in detail--what libraries I'm going to use, how I get from one object to another, inconsistencies in directory depth, etc.<br><br>
# 4. **In Conclusion**<br>
#     Ultimately, I'm grateful that I'm still working on my data organization the night before our third progress report is due. While this was not the most unorganized of data, it did also resist simple conversions like *pd.read_x*. It required me to make use of data pipelining skills and to write my first productive functions in Python.
#     Also, I do feel that I have a great background in NLP statistical techniques/ML because of the extent to which we explored them in the homeworks, whereas handling data in the wild is hard to teach. I'm 100% planning on continuing to expand my work on this project over the summer, hopefully expanding to complex ML techniques and eventually Network Theory!
#
# <a id='2'>

# %% [markdown]
# ## Preparing for Unsupervised Learning
# <a id='2a'>

# %%
emails_df.head(3)
# Out:
#                                       Message-ID  \
# 0  <29790972.1075855665306.JavaMail.evans@thyme>
# 1  <21975671.1075855665520.JavaMail.evans@thyme>
# 2   <7452188.1075855667684.JavaMail.evans@thyme>
#
#                                     Date  \
# 0  Wed, 13 Dec 2000 18:41:00 -0800 (PST)
# 1  Wed, 13 Dec 2000 08:35:00 -0800 (PST)
# 2   Mon, 9 Oct 2000 07:16:00 -0700 (PDT)
#
#                                       From                            To  \
# 0  1.11913372.-2@multexinvestornetwork.com              pallen@enron.com
# 1              messenger@ecm.bloomberg.com  Bloomberg Power Lines Report
# 2                  phillip.allen@enron.com         keith.holst@enron.com
#
#                                              Subject  \
# 0  December 14, 2000 - Bear Stearns' predictions ...
# 1                                                1.0
# 2        Consolidated positions: Issues & To Do list
#
#                                    Cc                  Mime-Version  \
# 0                                 1.0  text/plain; charset=us-ascii
# 1  text/plain; charset=ANSI_X3.4-1968              quoted-printable
# 2                                 1.0  text/plain; charset=us-ascii
#
#                                     Content-Type  \
# 0                                           7bit
# 1  "Bloomberg.com" <messenger@ecm.bloomberg.com>
# 2                                           7bit
#
#                            Content-Transfer-Encoding                 Bcc  \
# 0  Multex Investor <1.11913372.-2@multexinvestorn...  <pallen@enron.com>
# 1                           (undisclosed-recipients)
# 2                                    Phillip K Allen         Keith Holst
#
#   X-From                                               X-To  \
# 0
# 1         \Phillip_Allen_Dec2000\Notes Folders\All docum...
# 2
#
#                                                 X-cc       X-bcc    X-Folder  \
# 0  \Phillip_Allen_Dec2000\Notes Folders\All docum...     Allen-P  pallen.nsf
# 1                                            Allen-P  pallen.nsf        None
# 2  \Phillip_Allen_Dec2000\Notes Folders\All docum...     Allen-P  pallen.nsf
#
#   X-Origin X-FileName                                               Text  \
# 0     None       None  In today's Daily Update you'll find free repor...
# 1     None       None  Here is today's copy of Bloomberg Power Lines....
# 2     None       None  ---------------------- Forwarded by Phillip K ...
#
#           Folder     User
# 0  all_documents  allen-p
# 1  all_documents  allen-p
# 2  all_documents  allen-p

# %%
email_df = emails_df.copy()
del email_df["Message-ID"]
del email_df["Mime-Version"]
del email_df["Content-Type"]
del email_df["Content-Transfer-Encoding"]
del email_df["X-Origin"]
del email["X-FileName"]
del emails_df

# %%
email_df
# Out:
#                                          Date  \
# 0       Wed, 13 Dec 2000 18:41:00 -0800 (PST)
# 1       Wed, 13 Dec 2000 08:35:00 -0800 (PST)
# 2        Mon, 9 Oct 2000 07:16:00 -0700 (PDT)
# 3        Mon, 9 Oct 2000 07:00:00 -0700 (PDT)
# 4        Thu, 5 Oct 2000 06:26:00 -0700 (PDT)
# ...                                       ...
# 277293   Mon, 1 Oct 2001 13:26:44 -0700 (PDT)
# 277294   Mon, 1 Oct 2001 13:25:02 -0700 (PDT)
# 277295   Mon, 1 Oct 2001 09:47:52 -0700 (PDT)
# 277296   Mon, 1 Oct 2001 08:43:33 -0700 (PDT)
# 277297   Mon, 1 Oct 2001 08:33:33 -0700 (PDT)
#
#                                            From  \
# 0       1.11913372.-2@multexinvestornetwork.com
# 1                   messenger@ecm.bloomberg.com
# 2                       phillip.allen@enron.com
# 3                       phillip.allen@enron.com
# 4                       phillip.allen@enron.com
# ...                                         ...
# 277293                       t..lucci@enron.com
# 277294                       t..lucci@enron.com
# 277295                       t..lucci@enron.com
# 277296                       t..lucci@enron.com
# 277297                       t..lucci@enron.com
#
#                                                        To  \
# 0                                        pallen@enron.com
# 1                            Bloomberg Power Lines Report
# 2                                   keith.holst@enron.com
# 3                                   keith.holst@enron.com
# 4                                david.delainey@enron.com
# ...                                                   ...
# 277293  'poole.jr.@enron.com, robert.poole@atmosenergy...
# 277294            jbrewer.leathercenter@leathercenter.com
# 277295             webb@cisaustin.org, mgladwin@cisco.com
# 277296       'williams@enron.com, bob.williams@elpaso.com
# 277297                            bob.williams@elpaso.com
#
#                                                   Subject  \
# 0       December 14, 2000 - Bear Stearns' predictions ...
# 1                                                     1.0
# 2             Consolidated positions: Issues & To Do list
# 3             Consolidated positions: Issues & To Do list
# 4
# ...                                                   ...
# 277293                        RE: Enron Greeley Contracts
# 277294                                           RE: Hey!
# 277295
# 277296                                                RE:
# 277297
#
#                                         Cc  \
# 0                                      1.0
# 1       text/plain; charset=ANSI_X3.4-1968
# 2                                      1.0
# 3                                      1.0
# 4                                      1.0
# ...                                    ...
# 277293                                 1.0
# 277294                                 1.0
# 277295                                 1.0
# 277296                                 1.0
# 277297                                 1.0
#
#                                                       Bcc X-From  \
# 0                                      <pallen@enron.com>
# 1
# 2                                             Keith Holst
# 3                                             Keith Holst
# 4                                        David W Delainey
# ...                                                   ...    ...
# 277293  'Poole Jr., Robert W.' <Robert.Poole@atmosener...
# 277294          'jbrewer.LEATHERCENTER@leathercenter.com'
# 277295  Gonzalo Robles (E-mail) <webb@cisaustin.org>, ...
# 277296          'Williams, Bob' <Bob.Williams@ElPaso.com>
# 277297    Bob Williams (E-mail) <Bob.Williams@ElPaso.com>
#
#                                                      X-To  \
# 0
# 1       \Phillip_Allen_Dec2000\Notes Folders\All docum...
# 2
# 3
# 4
# ...                                                   ...
# 277293
# 277294
# 277295
# 277296
# 277297
#
#                                                      X-cc       X-bcc  \
# 0       \Phillip_Allen_Dec2000\Notes Folders\All docum...     Allen-P
# 1                                                 Allen-P  pallen.nsf
# 2       \Phillip_Allen_Dec2000\Notes Folders\All docum...     Allen-P
# 3       \Phillip_Allen_Dec2000\Notes Folders\All docum...     Allen-P
# 4       \Phillip_Allen_Dec2000\Notes Folders\All docum...     Allen-P
# ...                                                   ...         ...
# 277293                \PLUCCI (Non-Privileged)\Sent Items     Lucci-P
# 277294                \PLUCCI (Non-Privileged)\Sent Items     Lucci-P
# 277295                \PLUCCI (Non-Privileged)\Sent Items     Lucci-P
# 277296                \PLUCCI (Non-Privileged)\Sent Items     Lucci-P
# 277297                \PLUCCI (Non-Privileged)\Sent Items     Lucci-P
#
#                            X-Folder X-FileName  \
# 0                        pallen.nsf       None
# 1                              None       None
# 2                        pallen.nsf       None
# 3                        pallen.nsf       None
# 4                        pallen.nsf       None
# ...                             ...        ...
# 277293  PLUCCI (Non-Privileged).pst       None
# 277294  PLUCCI (Non-Privileged).pst       None
# 277295  PLUCCI (Non-Privileged).pst       None
# 277296  PLUCCI (Non-Privileged).pst       None
# 277297  PLUCCI (Non-Privileged).pst       None
#
#                                                      Text         Folder  \
# 0       In today's Daily Update you'll find free repor...  all_documents
# 1       Here is today's copy of Bloomberg Power Lines....  all_documents
# 2       ---------------------- Forwarded by Phillip K ...  all_documents
# 3       ---------------------- Forwarded by Phillip K ...  all_documents
# 4       Dave, \n\n Here are the names of the west desk...  all_documents
# ...                                                   ...            ...
# 277293  I will talk to Theresa and Gerald.  I'm sorry ...     sent_items
# 277294  What do you mean bummer, didn't you pick Oakla...     sent_items
# 277295  What's up you two losers, and I mean losers!  ...     sent_items
# 277296  No, Mark is going to Portland, and he just lef...     sent_items
# 277297  Hey what's up?  How many people picked the Col...     sent_items
#
#            User
# 0       allen-p
# 1       allen-p
# 2       allen-p
# 3       allen-p
# 4       allen-p
# ...         ...
# 277293  lucci-p
# 277294  lucci-p
# 277295  lucci-p
# 277296  lucci-p
# 277297  lucci-p
#
# [277298 rows x 15 columns]

# %%
file = open('email_df', 'wb')
pickle.dump(email_df, file, -1)
file.close()

# %% [markdown]
# **Short Summary**<br>
# In this project report, we're preparing the first half of the Enron Corpus for unsupervised learning, leaving it in our directory as a pickled pandas dataframe. In the next notebook, we'll hope to find "illegal" emails clustered together. From there we can move on to more classical means of classifying the emails.
